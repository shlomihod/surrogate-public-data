# %%
import os
import glob
import pickle
import time

os.environ["PRIVBAYES_BIN"] = "./ydnpd/harness/synthesis/privbayes/mac_bin"

import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from IPython.display import display, Markdown


import ydnpd
from additional import ADDITIONAL_EXPERIMENTS, ADDITIONAL_PATH
from ydnpd import EVALUATION_METRICS, ALL_EXPERIMENTS, Experiments

ADDITIONAL_DATASETS = sum(list(ADDITIONAL_EXPERIMENTS.values()), [])

with open("./results/harness.pkl", "rb") as f:
    utility_tasks_results = pickle.load(f)

for x in utility_tasks_results:
    if type(x["evaluation"]["error_rate_diff"]) == list:
        assert len(x["evaluation"]["error_rate_diff"]) == 1
        x["evaluation"]["error_rate_diff"] = x["evaluation"]["error_rate_diff"][0]

ALL_EXPERIMENTS_SIMPLIFIED = {name: exp.dev_names for name, exp in ALL_EXPERIMENTS.items()}
ADDITIONAL_EXPERIMENTS_SIMPLIFIED = {name: [x[0] for x in exp] for name, exp in ADDITIONAL_EXPERIMENTS.items()}
ALL_EXPERIMENTS_SIMPLIFIED_MERGED = {
    name: ADDITIONAL_EXPERIMENTS_SIMPLIFIED.get(name, []) + dev_names
    for name, dev_names in ALL_EXPERIMENTS_SIMPLIFIED.items()
}

reference_data_mapping = {
    "acs": "acs/national",
    "edad": "edad/2023",
    "we": "we/2023"
}

ALL_EXPERIMENTS_OBJ = {
    name: Experiments(reference_data_mapping.get(name, ""), dev_names)
    for name, dev_names in ALL_EXPERIMENTS_SIMPLIFIED_MERGED.items()
}

# remove all the real data and public data baselines,
# and now the MIX data
to_remove = [
    # 'acs/national',
    # 'edad/2023',
    # 'we/2023',
    # 'acs/massachusetts_upsampled',
    # 'edad/2020',
    # 'we/2018',
    ## MIX data
    # 'edad/gen-MIX-MAX',
    # 'acs/gen-MIX-MAX',
    # 'we/gen-MIX-MAX',
    # 'acs/gen-llama-MIX-MAX',
    # 'edad/gen-llama-MIX-MAX',
    # 'we/gen-llama-MIX-MAX',
    # 'acs/gen-claude-MIX-MAX',
    # 'edad/gen-claude-MIX-MAX',
    # 'we/gen-claude-MIX-MAX',
    # 'acs/gen-gpt-MIX-MAX',
    # 'edad/gen-gpt-MIX-MAX',
    # 'we/gen-gpt-MIX-MAX',
]

ALL_EXPERIMENTS_OBJ = {
    name: Experiments(exp.test_name, [dev for dev in exp.dev_names if dev not in to_remove])
    for name, exp in ALL_EXPERIMENTS_OBJ.items()
}

# NO MORE ABSOLUTE RANKINGS
# for hyperparameter tuning:
#   - we are going to do percent degradation
#   - as in how much worse is the method compared to the best method
#   - ok to aggregate across epsilon (or give conditional results)

# for privacy utility tradeoff:
#   - we are going to do a pareto frontier analysis
#   - we are going to do some sort of L1 advantage comparison
#   - here we care about epsilon [1,2,4]

# groupings of metrics

    # what is the pareto frontier? 
    # how correlated are the metrics with each other?

METRIC_DIRECTION = {
    # correlation based metrics 
    "total_variation_distance": "closer_to_zero_is_better",
    "pearson_corr_max_abs_diff": "closer_to_zero_is_better",
    "pearson_corr_avg_abs_diff": "closer_to_zero_is_better",
    "cramer_v_corr_max_abs_diff": "closer_to_zero_is_better",
    "cramer_v_corr_avg_abs_diff": "closer_to_zero_is_better",

    # marginals based metrics
    "marginals_3_max_abs_diff_error": "closer_to_zero_is_better",
    "marginals_3_avg_abs_diff_error": "closer_to_zero_is_better",
    "thresholded_marginals_3_max_abs_diff_error": "closer_to_zero_is_better",
    "thresholded_marginals_3_avg_abs_diff_error": "closer_to_zero_is_better",
    
    # classification based metrics
    "error_rate_diff": "closer_to_zero_is_better",  
    "aoc_diff": "closer_to_zero_is_better",  # auc

    # "error_rate_train_dataset": "closer_to_zero_is_better",
    # "error_rate_synth_dataset": "closer_to_zero_is_better",   
    # "aoc_train_dataset": "higher_is_better",
    # "aoc_synth_dataset": "higher_is_better",
}

metrics_marginals = [
    "marginals_3_max_abs_diff_error",
    "marginals_3_avg_abs_diff_error",
    "thresholded_marginals_3_max_abs_diff_error",
    "thresholded_marginals_3_avg_abs_diff_error"
]

metrics_correlations = [
    "total_variation_distance",
    "pearson_corr_max_abs_diff",
    "pearson_corr_avg_abs_diff",
    "cramer_v_corr_max_abs_diff",
    "cramer_v_corr_avg_abs_diff"
]

metrics_classification = [
    "error_rate_diff",
    "aoc_diff",
    # "error_rate_train_dataset",
    # "error_rate_synth_dataset",
    # "aoc_train_dataset",
    # "aoc_synth_dataset"
]

# error_rate_train_dataset / error_rate_synth_dataset / aoc_train_dataset / aoc_synth_dataset

# %%
ALL_EXPERIMENTS_OBJ
# Out:
# {'acs': Experiments(test_name='acs/national', dev_names=['acs/gen-MIX-MAX', 'acs/csv-gpt', 'acs/gen-gpt-MIX-MAX', 'acs/sdscm-gpt2', 'acs/gen-llama-MIX-MAX', 'acs/sdscm-olmo-1b-hf', 'acs/gen-gpt-MIX-UNIF', 'acs/gen-claude-MIX-MAX', 'acs/csv-claude', 'acs/gen-claude-MIX-UNIF', 'acs/gen-MIX-UNIF', 'acs/gen-llama-MIX-UNIF', 'acs/sdscm-llama-3-8b', 'acs/csv-llama', 'acs/national', 'acs/massachusetts_upsampled', 'acs/baseline_univariate', 'acs/baseline_domain', 'acs/arbitrary']),
#  'edad': Experiments(test_name='edad/2023', dev_names=['edad/gen-MIX-MAX', 'edad/csv-gpt', 'edad/gen-gpt-MIX-MAX', 'edad/sdscm-gpt2', 'edad/gen-llama-MIX-MAX', 'edad/sdscm-olmo-1b-hf', 'edad/gen-gpt-MIX-UNIF', 'edad/gen-claude-MIX-MAX', 'edad/csv-claude', 'edad/gen-claude-MIX-UNIF', 'edad/gen-MIX-UNIF', 'edad/gen-llama-MIX-UNIF', 'edad/sdscm-llama-3-8b', 'edad/csv-llama', 'edad/2023', 'edad/2020', 'edad/baseline_univariate', 'edad/baseline_domain', 'edad/arbitrary']),
#  'we': Experiments(test_name='we/2023', dev_names=['we/gen-MIX-MAX', 'we/csv-gpt', 'we/gen-gpt-MIX-MAX', 'we/sdscm-gpt2', 'we/gen-llama-MIX-MAX', 'we/sdscm-olmo-1b-hf', 'we/gen-gpt-MIX-UNIF', 'we/gen-claude-MIX-MAX', 'we/csv-claude', 'we/gen-claude-MIX-UNIF', 'we/gen-MIX-UNIF', 'we/gen-llama-MIX-UNIF', 'we/sdscm-llama-3-8b', 'we/csv-llama', 'we/2023', 'we/2018', 'we/baseline_univariate', 'we/baseline_domain', 'we/arbitrary'])}

# %%
utility_tasks_results[0:2]
# Out:
# [{'epsilon': 1,
#   'synth_name': 'privbayes',
#   'dataset_name': 'acs/national',
#   'hparams': {'theta': 2, 'epsilon_split': 0.1},
#   'evaluation': {'error_rate_train_dataset': 0.28339611706751666,
#    'error_rate_synth_dataset': 0.3078817733990148,
#    'pearson_corr_max_abs_diff': 0.17128663962155152,
#    'pearson_corr_train_dataset': [[0, 0, 0, 0, 0, 0, 0],
#     [0.14042261096610978, 0, 0, 0, 0, 0, 0],
#     [0.04169438956264132, 0.26182419188444295, 0, 0, 0, 0, 0],
#     [0.05412685965547898, 0.38847193160922217, 0.216169388767664, 0, 0, 0, 0],
#     [0.15208903067542315,
#      0.36340362674626603,
#      0.27534127657565277,
#      0.3214151651384918,
#      0,
#      0,
#      0],
#     [0.08215510231716827,
#      0.31089067901984646,
#      0.3460615926465102,
#      0.2595535407398533,
#      0.5219348794142432,
#      0,
#      0],
#     [0.05912784231797163,
#      0.2892374654111006,
#      0.07127893655076525,
#      0.7071067811865476,
#      0.2808729271546567,
#      0.2841759160273773,
#      0]],
#    'total_variation_distance': 0.4089667163437656,
#    'aoc_train_dataset': 0.09054710878554284,
#    'marginals_3_max_abs_diff_error': 0.04793840039741679,
#    'pearson_corr_avg_abs_diff': 0.05819882873728299,
#    '_timestamp': 1736987394.0781775,
#    'cramer_v_corr_synth_dataset': [[0, 0, 0, 0, 0, 0, 0],
#     [0.1349621587623327, 0, 0, 0, 0, 0, 0],
#     [0.022962208658975313, 0.047770738681154445, 0, 0, 0, 0, 0],
#     [0.010779294387599399, 0.2748834618370698, 0.0494389525703423, 0, 0, 0, 0],
#     [0.1414685210809892,
#      0.1546930553992662,
#      0.06495378897519939,
#      0.21335344790008706,
#      0,
#      0,
#      0],
#     [0.07326071059590179,
#      0.1753731399334932,
#      0.17757556742789635,
#      0.1296230221665872,
#      0.20959441283884356,
#      0,
#      0],
#     [0.010122592967372106,
#      0.17060142752289578,
#      0.17679989042270972,
#      0.5904966089946363,
#      0.17244112433475672,
#      0.2166736404931796,
#      0]],
#    '_runtime': 9.730810256,
#    'cramer_v_corr_avg_abs_diff': 0.042579870569510896,
#    '_step': 0,
#    'aoc_diff': -0.01812851274138383,
#    'error_rate_diff': -0.02448565633149813,
#    'aoc_synth_dataset': 0.10867562152692667,
#    'thresholded_marginals_3_max_abs_diff_error': 0.030551415797317436,
#    'cramer_v_corr_max_abs_diff': 0.12626954313739663,
#    'marginals_3_avg_abs_diff_error': 0.19604002554822228,
#    'pearson_corr_synth_dataset': [[0, 0, 0, 0, 0, 0, 0],
#     [0.13374954614666196, 0, 0, 0, 0, 0, 0],
#     [0.02295615748997215, 0.10621437323818067, 0, 0, 0, 0, 0],
#     [0.010778668201880838,
#      0.36232888994815154,
#      0.06974696882583781,
#      0,
#      0,
#      0,
#      0],
#     [0.14007379241844495,
#      0.32689985973785174,
#      0.18069299275751755,
#      0.2888646838154878,
#      0,
#      0,
#      0],
#     [0.07306489851450751,
#      0.365078975449421,
#      0.4488282070714969,
#      0.18031007592602752,
#      0.5323000665499342,
#      0,
#      0],
#     [0.010122074391922507,
#      0.23453722956393444,
#      0.24256557617231678,
#      0.640979036823217,
#      0.23692512909338292,
#      0.2929768280828039,
#      0]],
#    'thresholded_marginals_3_avg_abs_diff_error': 0.06277411113476687,
#    'cramer_v_corr_train_dataset': [[0, 0, 0, 0, 0, 0, 0],
#     [0.14182789027337817, 0, 0, 0, 0, 0, 0],
#     [0.04173067810767728, 0.12132364252835032, 0, 0, 0, 0, 0],
#     [0.05420632248959477, 0.2981040642653133, 0.1565564816470413, 0, 0, 0, 0],
#     [0.15387913781912355,
#      0.17444557298552496,
#      0.10825359589299358,
#      0.24001017187582677,
#      0,
#      0,
#      0],
#     [0.08243376505349945,
#      0.14628351906595913,
#      0.13941307075372222,
#      0.19004515973247318,
#      0.2039639909482794,
#      0,
#      0],
#     [0.05923147259990387,
#      0.2136539009978046,
#      0.05053034728531307,
#      0.7071067811865476,
#      0.20693742461101886,
#      0.20958338833402557,
#      0]]}},
#  {'epsilon': 1,
#   'synth_name': 'privbayes',
#   'dataset_name': 'acs/national',
#   'hparams': {'theta': 2, 'epsilon_split': 0.1},
#   'evaluation': {'error_rate_train_dataset': 0.28339611706751666,
#    'error_rate_synth_dataset': 0.3232396406838598,
#    'pearson_corr_max_abs_diff': 0.1962947809013366,
#    'pearson_corr_train_dataset': [[0, 0, 0, 0, 0, 0, 0],
#     [0.14042261096610978, 0, 0, 0, 0, 0, 0],
#     [0.04169438956264132, 0.26182419188444295, 0, 0, 0, 0, 0],
#     [0.05412685965547898, 0.38847193160922217, 0.216169388767664, 0, 0, 0, 0],
#     [0.15208903067542315,
#      0.36340362674626603,
#      0.27534127657565277,
#      0.3214151651384918,
#      0,
#      0,
#      0],
#     [0.08215510231716827,
#      0.31089067901984646,
#      0.3460615926465102,
#      0.2595535407398533,
#      0.5219348794142432,
#      0,
#      0],
#     [0.05912784231797163,
#      0.2892374654111006,
#      0.07127893655076525,
#      0.7071067811865476,
#      0.2808729271546567,
#      0.2841759160273773,
#      0]],
#    'total_variation_distance': 0.4187158469945355,
#    'aoc_train_dataset': 0.09054710878554284,
#    'marginals_3_max_abs_diff_error': 0.05414803775459513,
#    'pearson_corr_avg_abs_diff': 0.06428769016119479,
#    '_timestamp': 1736987402.7629929,
#    'cramer_v_corr_synth_dataset': [[0, 0, 0, 0, 0, 0, 0],
#     [0.16221103502146267, 0, 0, 0, 0, 0, 0],
#     [0.0392855769225572, 0.04093334585760036, 0, 0, 0, 0, 0],
#     [0.014729873405519827,
#      0.28297237055999647,
#      0.1356323650795058,
#      0,
#      0,
#      0,
#      0],
#     [0.19379638757845308,
#      0.17794654571551063,
#      0.057967757363174104,
#      0.141155613994816,
#      0,
#      0,
#      0],
#     [0.10463105773881572,
#      0.08390343499076462,
#      0.15976800780362224,
#      0.2014183588012634,
#      0.2184750869853757,
#      0,
#      0],
#     [0.01951359530203667,
#      0.16528740388077762,
#      0.1963631008552551,
#      0.6251666379185437,
#      0.08362872032562937,
#      0.18664259312718745,
#      0]],
#    '_runtime': 18.415501653,
#    'cramer_v_corr_avg_abs_diff': 0.045915847643923445,
#    '_step': 1,
#    'aoc_diff': -0.019945311415211164,
#    'error_rate_diff': -0.039843523616343135,
#    'aoc_synth_dataset': 0.110492420200754,
#    'thresholded_marginals_3_max_abs_diff_error': 0.03229011425732737,
#    'cramer_v_corr_max_abs_diff': 0.14583275356994202,
#    'marginals_3_avg_abs_diff_error': 0.20290611028315947,
#    'pearson_corr_synth_dataset': [[0, 0, 0, 0, 0, 0, 0],
#     [0.16011816456520436, 0, 0, 0, 0, 0, 0],
#     [0.039255296142269996, 0.09114873212587499, 0, 0, 0, 0, 0],
#     [0.014728275701297049, 0.3715374291635844, 0.1883789864480981, 0, 0, 0, 0],
#     [0.19025658042573634,
#      0.36970844790662377,
#      0.16179727513783307,
#      0.19576175233487303,
#      0,
#      0,
#      0],
#     [0.10406298527320476,
#      0.1843965688401265,
#      0.41179808656399924,
#      0.2739512850198621,
#      0.5481742089802505,
#      0,
#      0],
#     [0.019509881165377857,
#      0.2276159372072928,
#      0.26757371745210184,
#      0.6623652903263624,
#      0.11745030340996973,
#      0.2552117490536876,
#      0]],
#    'thresholded_marginals_3_avg_abs_diff_error': 0.06594634873323398,
#    'cramer_v_corr_train_dataset': [[0, 0, 0, 0, 0, 0, 0],
#     [0.14182789027337817, 0, 0, 0, 0, 0, 0],
#     [0.04173067810767728, 0.12132364252835032, 0, 0, 0, 0, 0],
#     [0.05420632248959477, 0.2981040642653133, 0.1565564816470413, 0, 0, 0, 0],
#     [0.15387913781912355,
#      0.17444557298552496,
#      0.10825359589299358,
#      0.24001017187582677,
#      0,
#      0,
#      0],
#     [0.08243376505349945,
#      0.14628351906595913,
#      0.13941307075372222,
#      0.19004515973247318,
#      0.2039639909482794,
#      0,
#      0],
#     [0.05923147259990387,
#      0.2136539009978046,
#      0.05053034728531307,
#      0.7071067811865476,
#      0.20693742461101886,
#      0.20958338833402557,
#      0]]}}]

# %% [markdown]
# ## Absolute rankings

# %%
# suppress warnings
import warnings
warnings.filterwarnings("ignore")

column_to_rank_on = 'correspond_test'
for experiments_name, experiments in ALL_EXPERIMENTS_OBJ.items():

    display(Markdown(f"## {experiments_name.upper()}"))

    datasets = {}

    for metric in METRIC_DIRECTION.keys():

        # if metric not in metrics_marginals:
        #     continue

        # if experiments_name != 'acs':
        #     continue

        display(Markdown(f"### {metric}"))
        with pd.option_context("display.max_rows", None):
            try: 
                df_extract_all = ydnpd.UtilityTask.evaluate(utility_tasks_results, experiments, metric).multiply(100).round(2)
                
                # flatten df_extract_all
                df_extract_all = df_extract_all.reset_index()

                df_extract_all_smaller = df_extract_all[['synth_name', 'experiment', 'epsilon', column_to_rank_on]] 

                # # rank based on lower or higher being better (closer_to_zero_is_better is default for lower_is_better)
                # metric_direction = METRIC_DIRECTION[metric]

                # df_extract_all_smaller.loc[:, "_rank_value"] = df_extract_all_smaller[column_to_rank_on]

                # if metric_direction == "closer_to_zero_is_better":
                #     df_extract_all_smaller.loc[:, "_rank_value"] = df_extract_all_smaller["_rank_value"].abs()
                #     ascending = True
                #     aggfunc = "min"
                # elif metric_direction == "lower_is_better":
                #     ascending = True
                #     aggfunc = "min"
                # else:  # "higher_is_better"
                #     ascending = False
                #     aggfunc = "max"

                # idx = df_extract_all_smaller.groupby(
                #     ['synth_name', 'experiment', 'epsilon']
                # )["_rank_value"].idxmin() if ascending else df_extract_all_smaller.groupby(
                #     ['synth_name', 'experiment', 'epsilon']
                # )["_rank_value"].idxmax()

                # df_best = df_extract_all_smaller.loc[idx].reset_index(drop=True)

                # df_experiment_best = df_best.groupby(['synth_name', 'epsilon', 'experiment'])[column_to_rank_on].min().reset_index()
                # df_experiment_best['rank'] = df_experiment_best.groupby(['synth_name', 'epsilon'])[column_to_rank_on].rank(method='dense', ascending=True)
                # df_experiment_best = df_experiment_best.sort_values(['synth_name', 'epsilon', 'rank'])

                # df_final = pd.merge(df_best, df_experiment_best[['synth_name', 'epsilon', 'experiment', 'rank']],
                #                     on=['synth_name', 'epsilon', 'experiment'],
                #                     how='left')

                # df_final_avg = df_final.groupby(['experiment','synth_name'])['rank'].mean().reset_index()

                # # for synth_name in df_final_avg['synth_name'].unique():
                # df_final_avg.groupby(['experiment','synth_name'])['rank'].mean().reset_index()
                df_extract_all_smaller.to_csv(f"./results/all_rankings/{metric}_{experiments_name}.csv")
                # df_final_avg.to_csv(f"./results/all_rankings/{metric}_{experiments_name}.csv")
            except Exception as e:
                print(f"Error: {e}")
                continue
# Out:
# ## ACS
# ### total_variation_distance
# ### pearson_corr_max_abs_diff
# ### pearson_corr_avg_abs_diff
# ### cramer_v_corr_max_abs_diff
# ### cramer_v_corr_avg_abs_diff
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[94], line 23
#      21 with pd.option_context("display.max_rows", None):
#      22     try:
# ---> 23         df_extract_all = ydnpd.UtilityTask.evaluate(utility_tasks_results, experiments, metric).multiply(100).round(2)
#      25         # flatten df_extract_all
#      26         df_extract_all = df_extract_all.reset_index()
#
# File ~/Documents/YDNPD_clones/clone4/YDNPD/ydnpd/harness/tasks/utility.py:330, in UtilityTask.evaluate(hparam_results, experiments, metric)
#     324     return function
#     327 try:
#     328     hparams_evaluation_df = (
#     329         pd.concat(
# --> 330             [
#     331                 (
#     332                     pd.DataFrame(best_hparams_df[dev_name])
#     333                     .apply(
#     334                         extractor(experiments.test_name, dev_name),
#     335                         result_type="expand",
#     336                         axis=1,
#     337                     )
#     338                     .reset_index()
#     339                     .assign(
#     340                         dev_name=dev_name,
#     341                         test_name=experiments.test_name,
#     342                         experiment=f"{experiments.test_name}/{dev_name}",
#     343                     )
#     344                 )
#     345                 for dev_name in experiments.dev_names
#     346             ]
#     347         )
#     348         .set_index(["synth_name", "experiment", "epsilon"])
#     349         .sort_index()
#     350         .drop(columns=["test_name", "dev_name"])
#     351     )
#     352 except Exception as e:
#     353     print(f"Error in evaluate method: {e}")
#
# File ~/Documents/YDNPD_clones/clone4/YDNPD/ydnpd/harness/tasks/utility.py:332, in <listcomp>(.0)
#     324     return function
#     327 try:
#     328     hparams_evaluation_df = (
#     329         pd.concat(
#     330             [
#     331                 (
# --> 332                     pd.DataFrame(best_hparams_df[dev_name])
#     333                     .apply(
#     334                         extractor(experiments.test_name, dev_name),
#     335                         result_type="expand",
#     336                         axis=1,
#     337                     )
#     338                     .reset_index()
#     339                     .assign(
#     340                         dev_name=dev_name,
#     341                         test_name=experiments.test_name,
#     342                         experiment=f"{experiments.test_name}/{dev_name}",
#     343                     )
#     344                 )
#     345                 for dev_name in experiments.dev_names
#     346             ]
#     347         )
#     348         .set_index(["synth_name", "experiment", "epsilon"])
#     349         .sort_index()
#     350         .drop(columns=["test_name", "dev_name"])
#     351     )
#     352 except Exception as e:
#     353     print(f"Error in evaluate method: {e}")
#
# File ~/opt/miniconda3/envs/fairly_uncertain/lib/python3.10/site-packages/pandas/core/frame.py:10374, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10360 from pandas.core.apply import frame_apply
#   10362 op = frame_apply(
#   10363     self,
#   10364     func=func,
#    (...)
#   10372     kwargs=kwargs,
#   10373 )
# > 10374 return op.apply().__finalize__(self, method="apply")
#
# File ~/opt/miniconda3/envs/fairly_uncertain/lib/python3.10/site-packages/pandas/core/apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# --> 916 return self.apply_standard()
#
# File ~/opt/miniconda3/envs/fairly_uncertain/lib/python3.10/site-packages/pandas/core/apply.py:1063, in FrameApply.apply_standard(self)
#    1061 def apply_standard(self):
#    1062     if self.engine == "python":
# -> 1063         results, res_index = self.apply_series_generator()
#    1064     else:
#    1065         results, res_index = self.apply_series_numba()
#
# File ~/opt/miniconda3/envs/fairly_uncertain/lib/python3.10/site-packages/pandas/core/apply.py:1081, in FrameApply.apply_series_generator(self)
#    1078 with option_context("mode.chained_assignment", None):
#    1079     for i, v in enumerate(series_gen):
#    1080         # ignore SettingWithCopy here in case the user mutates
# -> 1081         results[i] = self.func(v, *self.args, **self.kwargs)
#    1082         if isinstance(results[i], ABCSeries):
#    1083             # If we have a view on v, we need to make a copy because
#    1084             #  series_generator will swap out the underlying data
#    1085             results[i] = results[i].copy(deep=False)
#
# File ~/Documents/YDNPD_clones/clone4/YDNPD/ydnpd/harness/tasks/utility.py:273, in UtilityTask.evaluate.<locals>.extractor.<locals>.function(r)
#     264 best_dev_result = results_df.loc[
#     265     (results_df["dataset_name"] == dev_name)
#     266     & (results_df["hparams_frozen"] == hparams)
#     267     & base_mask,
#     268     metric_column,
#     269 ]
#     271 # Fetch corresponding test result
#     272 correspond_test_result = results_df.loc[
# --> 273     (results_df["dataset_name"] == test_name)
#     274     & (results_df["hparams_frozen"] == hparams)
#     275     & base_mask,
#     276     metric_column,
#     277 ]
#     279 # Fetch all test results for quantile computation
#     280 test_results = results_df.loc[
#     281     (results_df["dataset_name"] == test_name) & base_mask,
#     282     metric_column,
#     283 ]
#
# File ~/opt/miniconda3/envs/fairly_uncertain/lib/python3.10/site-packages/pandas/core/ops/common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~/opt/miniconda3/envs/fairly_uncertain/lib/python3.10/site-packages/pandas/core/arraylike.py:40, in OpsMixin.__eq__(self, other)
#      38 @unpack_zerodim_and_defer("__eq__")
#      39 def __eq__(self, other):
# ---> 40     return self._cmp_method(other, operator.eq)
#
# File ~/opt/miniconda3/envs/fairly_uncertain/lib/python3.10/site-packages/pandas/core/series.py:6121, in Series._cmp_method(self, other, op)
#    6117 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
#    6119 res_values = ops.comparison_op(lvalues, rvalues, op)
# -> 6121 return self._construct_result(res_values, name=res_name)
#
# File ~/opt/miniconda3/envs/fairly_uncertain/lib/python3.10/site-packages/pandas/core/series.py:6231, in Series._construct_result(self, result, name)
#    6228 # TODO: result should always be ArrayLike, but this fails for some
#    6229 #  JSONArray tests
#    6230 dtype = getattr(result, "dtype", None)
# -> 6231 out = self._constructor(result, index=self.index, dtype=dtype, copy=False)
#    6232 out = out.__finalize__(self)
#    6234 # Set the result's name after __finalize__ is called because __finalize__
#    6235 #  would set it back to self.name
#
# File ~/opt/miniconda3/envs/fairly_uncertain/lib/python3.10/site-packages/pandas/core/series.py:592, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     589     elif manager == "array":
#     590         data = SingleArrayManager.from_array(data, index)
# --> 592 NDFrame.__init__(self, data)
#     593 self.name = name
#     594 self._set_axis(0, index)
#
# File ~/opt/miniconda3/envs/fairly_uncertain/lib/python3.10/site-packages/pandas/core/generic.py:283, in NDFrame.__init__(self, data)
#     281 object.__setattr__(self, "_item_cache", {})
#     282 object.__setattr__(self, "_attrs", {})
# --> 283 object.__setattr__(self, "_flags", Flags(self, allows_duplicate_labels=True))
#
# File ~/opt/miniconda3/envs/fairly_uncertain/lib/python3.10/site-packages/pandas/core/flags.py:51, in Flags.__init__(self, obj, allows_duplicate_labels)
#      11 """
#      12 Flags that apply to pandas objects.
#      13
#    (...)
#      46 <Flags(allows_duplicate_labels=True)>
#      47 """
#      49 _keys: set[str] = {"allows_duplicate_labels"}
# ---> 51 def __init__(self, obj: NDFrame, *, allows_duplicate_labels: bool) -> None:
#      52     self._allows_duplicate_labels = allows_duplicate_labels
#      53     self._obj = weakref.ref(obj)
#
# KeyboardInterrupt:

# %%
# load from results/all_rankings
all_results = {}
for filepath in glob.glob("./results/all_rankings/*"):

    df = pd.read_csv(filepath)
    all_results[filepath.split('/')[3].split('.')[0]] = df

# %%
all_results.keys()
# Out:
# dict_keys(['pearson_corr_avg_abs_diff_edad', 'marginals_3_max_abs_diff_error_we', 'cramer_v_corr_avg_abs_diff_we', 'cramer_v_corr_max_abs_diff_edad', 'aoc_diff_we', 'total_variation_distance_acs', 'cramer_v_corr_avg_abs_diff_acs', 'marginals_3_avg_abs_diff_error_edad', 'error_rate_diff_acs', 'cramer_v_corr_max_abs_diff_acs', 'total_variation_distance_we', 'cramer_v_corr_avg_abs_diff_edad', 'thresholded_marginals_3_max_abs_diff_error_acs', 'total_variation_distance_edad', 'thresholded_marginals_3_avg_abs_diff_error_edad', 'pearson_corr_avg_abs_diff_we', 'pearson_corr_max_abs_diff_acs', 'pearson_corr_avg_abs_diff_acs', 'error_rate_synth_dataset_we', 'pearson_corr_max_abs_diff_edad', 'error_rate_train_dataset_we', 'super_ranking', 'thresholded_marginals_3_max_abs_diff_error_we', 'thresholded_marginals_3_avg_abs_diff_error_acs', 'marginals_3_max_abs_diff_error_edad', 'marginals_3_avg_abs_diff_error_acs', 'marginals_3_avg_abs_diff_error_we', 'pearson_corr_max_abs_diff_we', 'marginals_3_max_abs_diff_error_acs', 'error_rate_train_dataset_acs', 'aoc_diff_acs', 'error_rate_diff_we', 'error_rate_synth_dataset_acs', 'aoc_train_dataset_we', 'aoc_synth_dataset_we', 'cramer_v_corr_max_abs_diff_we', 'aoc_synth_dataset_acs', 'aoc_train_dataset_acs', 'thresholded_marginals_3_max_abs_diff_error_edad', 'thresholded_marginals_3_avg_abs_diff_error_we'])

# %%
df_max_marg = all_results['marginals_3_max_abs_diff_error_acs']
df_avg_marg = all_results['marginals_3_avg_abs_diff_error_acs']
df_max_marg_t = all_results['thresholded_marginals_3_max_abs_diff_error_acs']
df_avg_marg_t = all_results['thresholded_marginals_3_avg_abs_diff_error_acs']

# %% [markdown]
# ### Marginals

# %%
df_max_marg[(df_max_marg['epsilon'] == 4)].sort_values('correspond_test').groupby(['synth_name']).describe()['correspond_test']
# Out:
#             count       mean       std    min    25%    50%     75%    max
# synth_name
# aim_jax      19.0   0.617895  0.340760   0.40   0.42   0.42   0.810   1.31
# gem          19.0  36.252632  0.122149  36.15  36.17  36.24  36.270  36.57
# privbayes    19.0   3.491053  0.555077   3.08   3.08   3.31   3.555   4.95

# %%
df_avg_marg[(df_avg_marg['epsilon'] == 4)].sort_values('correspond_test').groupby(['synth_name']).describe()['correspond_test']
# Out:
#             count        mean       std     min     25%     50%      75%  \
# synth_name
# aim_jax      19.0    4.937368  0.111597    4.81    4.81    5.03    5.030
# gem          19.0  179.752105  0.455785  178.85  179.37  179.88  180.015
# privbayes    19.0   15.430526  2.819910   14.33   14.33   14.33   15.010
#
#                max
# synth_name
# aim_jax       5.03
# gem         180.63
# privbayes    25.38

# %%
df_max_marg_t[(df_max_marg_t['epsilon'] == 4)].sort_values('correspond_test').groupby(['synth_name']).describe()['correspond_test']
# Out:
#             count       mean       std    min    25%    50%    75%    max
# synth_name
# aim_jax      19.0   0.614737  0.296111   0.48   0.48   0.50   0.50   1.28
# gem          19.0  52.255263  0.368682  51.63  51.88  52.31  52.56  52.68
# privbayes    19.0   4.126316  2.290085   2.58   2.58   2.88   4.74   8.94

# %%
df_avg_marg_t[(df_avg_marg_t['epsilon'] == 4)].sort_values('correspond_test').groupby(['synth_name', 'experiment']).describe()['correspond_test'].sort_values('mean')
# Out:
#                                                      count   mean  std    min  \
# synth_name experiment
# aim_jax    acs/national/acs/national                   1.0   0.85  NaN   0.85
#            acs/national/acs/baseline_domain            1.0   0.85  NaN   0.85
#            acs/national/acs/csv-claude                 1.0   0.85  NaN   0.85
#            acs/national/acs/csv-gpt                    1.0   0.85  NaN   0.85
#            acs/national/acs/csv-llama                  1.0   0.85  NaN   0.85
#            acs/national/acs/gen-MIX-MAX                1.0   0.85  NaN   0.85
#            acs/national/acs/sdscm-llama-3-8b           1.0   0.85  NaN   0.85
#            acs/national/acs/gen-claude-MIX-MAX         1.0   0.85  NaN   0.85
#            acs/national/acs/sdscm-gpt2                 1.0   0.85  NaN   0.85
#            acs/national/acs/gen-gpt-MIX-UNIF           1.0   0.85  NaN   0.85
#            acs/national/acs/sdscm-olmo-1b-hf           1.0   0.88  NaN   0.88
#            acs/national/acs/massachusetts_upsampled    1.0   0.88  NaN   0.88
#            acs/national/acs/gen-llama-MIX-UNIF         1.0   0.88  NaN   0.88
#            acs/national/acs/arbitrary                  1.0   0.88  NaN   0.88
#            acs/national/acs/gen-gpt-MIX-MAX            1.0   0.88  NaN   0.88
#            acs/national/acs/gen-claude-MIX-UNIF        1.0   0.88  NaN   0.88
#            acs/national/acs/gen-MIX-UNIF               1.0   0.88  NaN   0.88
#            acs/national/acs/gen-llama-MIX-MAX          1.0   0.88  NaN   0.88
#            acs/national/acs/baseline_univariate        1.0   2.07  NaN   2.07
# privbayes  acs/national/acs/gen-MIX-UNIF               1.0   4.11  NaN   4.11
#            acs/national/acs/gen-claude-MIX-UNIF        1.0   4.11  NaN   4.11
#            acs/national/acs/gen-gpt-MIX-MAX            1.0   4.11  NaN   4.11
#            acs/national/acs/gen-gpt-MIX-UNIF           1.0   4.11  NaN   4.11
#            acs/national/acs/gen-llama-MIX-MAX          1.0   4.11  NaN   4.11
#            acs/national/acs/massachusetts_upsampled    1.0   4.11  NaN   4.11
#            acs/national/acs/national                   1.0   4.11  NaN   4.11
#            acs/national/acs/csv-llama                  1.0   4.11  NaN   4.11
#            acs/national/acs/gen-llama-MIX-UNIF         1.0   4.11  NaN   4.11
#            acs/national/acs/csv-gpt                    1.0   4.11  NaN   4.11
#            acs/national/acs/gen-MIX-MAX                1.0   4.69  NaN   4.69
#            acs/national/acs/gen-claude-MIX-MAX         1.0   5.50  NaN   5.50
#            acs/national/acs/sdscm-olmo-1b-hf           1.0   5.50  NaN   5.50
#            acs/national/acs/csv-claude                 1.0   5.82  NaN   5.82
#            acs/national/acs/arbitrary                  1.0   5.82  NaN   5.82
#            acs/national/acs/sdscm-gpt2                 1.0   9.35  NaN   9.35
#            acs/national/acs/sdscm-llama-3-8b           1.0   9.66  NaN   9.66
#            acs/national/acs/baseline_domain            1.0   9.66  NaN   9.66
#            acs/national/acs/baseline_univariate        1.0   9.66  NaN   9.66
# gem        acs/national/acs/national                   1.0  62.12  NaN  62.12
#            acs/national/acs/gen-MIX-UNIF               1.0  62.12  NaN  62.12
#            acs/national/acs/csv-claude                 1.0  62.12  NaN  62.12
#            acs/national/acs/massachusetts_upsampled    1.0  62.14  NaN  62.14
#            acs/national/acs/gen-gpt-MIX-UNIF           1.0  62.14  NaN  62.14
#            acs/national/acs/baseline_univariate        1.0  62.24  NaN  62.24
#            acs/national/acs/csv-llama                  1.0  62.50  NaN  62.50
#            acs/national/acs/baseline_domain            1.0  62.50  NaN  62.50
#            acs/national/acs/csv-gpt                    1.0  62.56  NaN  62.56
#            acs/national/acs/arbitrary                  1.0  62.63  NaN  62.63
#            acs/national/acs/sdscm-gpt2                 1.0  64.50  NaN  64.50
#            acs/national/acs/sdscm-olmo-1b-hf           1.0  64.81  NaN  64.81
#            acs/national/acs/gen-claude-MIX-UNIF        1.0  64.83  NaN  64.83
#            acs/national/acs/gen-llama-MIX-MAX          1.0  64.83  NaN  64.83
#            acs/national/acs/gen-gpt-MIX-MAX            1.0  64.83  NaN  64.83
#            acs/national/acs/gen-claude-MIX-MAX         1.0  65.86  NaN  65.86
#            acs/national/acs/sdscm-llama-3-8b           1.0  65.86  NaN  65.86
#            acs/national/acs/gen-MIX-MAX                1.0  65.86  NaN  65.86
#            acs/national/acs/gen-llama-MIX-UNIF         1.0  65.94  NaN  65.94
#
#                                                        25%    50%    75%  \
# synth_name experiment
# aim_jax    acs/national/acs/national                  0.85   0.85   0.85
#            acs/national/acs/baseline_domain           0.85   0.85   0.85
#            acs/national/acs/csv-claude                0.85   0.85   0.85
#            acs/national/acs/csv-gpt                   0.85   0.85   0.85
#            acs/national/acs/csv-llama                 0.85   0.85   0.85
#            acs/national/acs/gen-MIX-MAX               0.85   0.85   0.85
#            acs/national/acs/sdscm-llama-3-8b          0.85   0.85   0.85
#            acs/national/acs/gen-claude-MIX-MAX        0.85   0.85   0.85
#            acs/national/acs/sdscm-gpt2                0.85   0.85   0.85
#            acs/national/acs/gen-gpt-MIX-UNIF          0.85   0.85   0.85
#            acs/national/acs/sdscm-olmo-1b-hf          0.88   0.88   0.88
#            acs/national/acs/massachusetts_upsampled   0.88   0.88   0.88
#            acs/national/acs/gen-llama-MIX-UNIF        0.88   0.88   0.88
#            acs/national/acs/arbitrary                 0.88   0.88   0.88
#            acs/national/acs/gen-gpt-MIX-MAX           0.88   0.88   0.88
#            acs/national/acs/gen-claude-MIX-UNIF       0.88   0.88   0.88
#            acs/national/acs/gen-MIX-UNIF              0.88   0.88   0.88
#            acs/national/acs/gen-llama-MIX-MAX         0.88   0.88   0.88
#            acs/national/acs/baseline_univariate       2.07   2.07   2.07
# privbayes  acs/national/acs/gen-MIX-UNIF              4.11   4.11   4.11
#            acs/national/acs/gen-claude-MIX-UNIF       4.11   4.11   4.11
#            acs/national/acs/gen-gpt-MIX-MAX           4.11   4.11   4.11
#            acs/national/acs/gen-gpt-MIX-UNIF          4.11   4.11   4.11
#            acs/national/acs/gen-llama-MIX-MAX         4.11   4.11   4.11
#            acs/national/acs/massachusetts_upsampled   4.11   4.11   4.11
#            acs/national/acs/national                  4.11   4.11   4.11
#            acs/national/acs/csv-llama                 4.11   4.11   4.11
#            acs/national/acs/gen-llama-MIX-UNIF        4.11   4.11   4.11
#            acs/national/acs/csv-gpt                   4.11   4.11   4.11
#            acs/national/acs/gen-MIX-MAX               4.69   4.69   4.69
#            acs/national/acs/gen-claude-MIX-MAX        5.50   5.50   5.50
#            acs/national/acs/sdscm-olmo-1b-hf          5.50   5.50   5.50
#            acs/national/acs/csv-claude                5.82   5.82   5.82
#            acs/national/acs/arbitrary                 5.82   5.82   5.82
#            acs/national/acs/sdscm-gpt2                9.35   9.35   9.35
#            acs/national/acs/sdscm-llama-3-8b          9.66   9.66   9.66
#            acs/national/acs/baseline_domain           9.66   9.66   9.66
#            acs/national/acs/baseline_univariate       9.66   9.66   9.66
# gem        acs/national/acs/national                 62.12  62.12  62.12
#            acs/national/acs/gen-MIX-UNIF             62.12  62.12  62.12
#            acs/national/acs/csv-claude               62.12  62.12  62.12
#            acs/national/acs/massachusetts_upsampled  62.14  62.14  62.14
#            acs/national/acs/gen-gpt-MIX-UNIF         62.14  62.14  62.14
#            acs/national/acs/baseline_univariate      62.24  62.24  62.24
#            acs/national/acs/csv-llama                62.50  62.50  62.50
#            acs/national/acs/baseline_domain          62.50  62.50  62.50
#            acs/national/acs/csv-gpt                  62.56  62.56  62.56
#            acs/national/acs/arbitrary                62.63  62.63  62.63
#            acs/national/acs/sdscm-gpt2               64.50  64.50  64.50
#            acs/national/acs/sdscm-olmo-1b-hf         64.81  64.81  64.81
#            acs/national/acs/gen-claude-MIX-UNIF      64.83  64.83  64.83
#            acs/national/acs/gen-llama-MIX-MAX        64.83  64.83  64.83
#            acs/national/acs/gen-gpt-MIX-MAX          64.83  64.83  64.83
#            acs/national/acs/gen-claude-MIX-MAX       65.86  65.86  65.86
#            acs/national/acs/sdscm-llama-3-8b         65.86  65.86  65.86
#            acs/national/acs/gen-MIX-MAX              65.86  65.86  65.86
#            acs/national/acs/gen-llama-MIX-UNIF       65.94  65.94  65.94
#
#                                                        max
# synth_name experiment
# aim_jax    acs/national/acs/national                  0.85
#            acs/national/acs/baseline_domain           0.85
#            acs/national/acs/csv-claude                0.85
#            acs/national/acs/csv-gpt                   0.85
#            acs/national/acs/csv-llama                 0.85
#            acs/national/acs/gen-MIX-MAX               0.85
#            acs/national/acs/sdscm-llama-3-8b          0.85
#            acs/national/acs/gen-claude-MIX-MAX        0.85
#            acs/national/acs/sdscm-gpt2                0.85
#            acs/national/acs/gen-gpt-MIX-UNIF          0.85
#            acs/national/acs/sdscm-olmo-1b-hf          0.88
#            acs/national/acs/massachusetts_upsampled   0.88
#            acs/national/acs/gen-llama-MIX-UNIF        0.88
#            acs/national/acs/arbitrary                 0.88
#            acs/national/acs/gen-gpt-MIX-MAX           0.88
#            acs/national/acs/gen-claude-MIX-UNIF       0.88
#            acs/national/acs/gen-MIX-UNIF              0.88
#            acs/national/acs/gen-llama-MIX-MAX         0.88
#            acs/national/acs/baseline_univariate       2.07
# privbayes  acs/national/acs/gen-MIX-UNIF              4.11
#            acs/national/acs/gen-claude-MIX-UNIF       4.11
#            acs/national/acs/gen-gpt-MIX-MAX           4.11
#            acs/national/acs/gen-gpt-MIX-UNIF          4.11
#            acs/national/acs/gen-llama-MIX-MAX         4.11
#            acs/national/acs/massachusetts_upsampled   4.11
#            acs/national/acs/national                  4.11
#            acs/national/acs/csv-llama                 4.11
#            acs/national/acs/gen-llama-MIX-UNIF        4.11
#            acs/national/acs/csv-gpt                   4.11
#            acs/national/acs/gen-MIX-MAX               4.69
#            acs/national/acs/gen-claude-MIX-MAX        5.50
#            acs/national/acs/sdscm-olmo-1b-hf          5.50
#            acs/national/acs/csv-claude                5.82
#            acs/national/acs/arbitrary                 5.82
#            acs/national/acs/sdscm-gpt2                9.35
#            acs/national/acs/sdscm-llama-3-8b          9.66
#            acs/national/acs/baseline_domain           9.66
#            acs/national/acs/baseline_univariate       9.66
# gem        acs/national/acs/national                 62.12
#            acs/national/acs/gen-MIX-UNIF             62.12
#            acs/national/acs/csv-claude               62.12
#            acs/national/acs/massachusetts_upsampled  62.14
#            acs/national/acs/gen-gpt-MIX-UNIF         62.14
#            acs/national/acs/baseline_univariate      62.24
#            acs/national/acs/csv-llama                62.50
#            acs/national/acs/baseline_domain          62.50
#            acs/national/acs/csv-gpt                  62.56
#            acs/national/acs/arbitrary                62.63
#            acs/national/acs/sdscm-gpt2               64.50
#            acs/national/acs/sdscm-olmo-1b-hf         64.81
#            acs/national/acs/gen-claude-MIX-UNIF      64.83
#            acs/national/acs/gen-llama-MIX-MAX        64.83
#            acs/national/acs/gen-gpt-MIX-MAX          64.83
#            acs/national/acs/gen-claude-MIX-MAX       65.86
#            acs/national/acs/sdscm-llama-3-8b         65.86
#            acs/national/acs/gen-MIX-MAX              65.86
#            acs/national/acs/gen-llama-MIX-UNIF       65.94

# %% [markdown]
# ## Correlations

# %%
# df_extract_all_smaller[(df_extract_all_smaller['epsilon'] == 4)].sort_values('correspond_test').groupby(['synth_name', 'experiment']).describe()['correspond_test']

# %%
df_final_avg[df_final_avg['synth_name'] == 'privbayes'].sort_values('rank')
# Out:
#                                   experiment synth_name  rank
# 47                 acs/national/acs/national  privbayes  1.00
# 56         acs/national/acs/sdscm-olmo-1b-hf  privbayes  1.25
# 50               acs/national/acs/sdscm-gpt2  privbayes  1.25
# 11               acs/national/acs/csv-claude  privbayes  1.25
# 17                acs/national/acs/csv-llama  privbayes  1.25
# 53         acs/national/acs/sdscm-llama-3-8b  privbayes  1.50
# 44  acs/national/acs/massachusetts_upsampled  privbayes  1.75
# 41       acs/national/acs/gen-llama-MIX-UNIF  privbayes  1.75
# 35         acs/national/acs/gen-gpt-MIX-UNIF  privbayes  1.75
# 32          acs/national/acs/gen-gpt-MIX-MAX  privbayes  1.75
# 2                 acs/national/acs/arbitrary  privbayes  1.75
# 20              acs/national/acs/gen-MIX-MAX  privbayes  1.75
# 14                  acs/national/acs/csv-gpt  privbayes  1.75
# 26       acs/national/acs/gen-claude-MIX-MAX  privbayes  1.75
# 29      acs/national/acs/gen-claude-MIX-UNIF  privbayes  1.75
# 23             acs/national/acs/gen-MIX-UNIF  privbayes  2.00
# 38        acs/national/acs/gen-llama-MIX-MAX  privbayes  2.00
# 5           acs/national/acs/baseline_domain  privbayes  2.75
# 8       acs/national/acs/baseline_univariate  privbayes  4.00

# %%
# slightly hacky, just grabbing all files in the rankings folder
RANKINGS_FOLDER = "./results/all_rankings"

ranking_files = glob.glob(os.path.join(RANKINGS_FOLDER, "*.csv"))

dfs = []

for file_path in ranking_files:
    file_name = os.path.basename(file_path) 
    file_stem, _ = os.path.splitext(file_name)

    parts = file_stem.split("_")
    experiments_name = parts[-1]           
    metric = "_".join(parts[:-1])          

    df = pd.read_csv(file_path)

    df["metric"] = metric
    df["experiments_name"] = experiments_name

    dfs.append(df)

all_ranks_df = pd.concat(dfs, ignore_index=True)

# ccreate a super ranking by averaging ranks across all metrics
# for each (experiment, synth_name) within each experiments_name 
super_rank_df = (
    all_ranks_df
    .groupby(["experiments_name", "experiment", "synth_name"], as_index=False)["rank"]
    .mean()
    .rename(columns={"rank": "super_rank"})
)

super_rank_df = super_rank_df.sort_values(["experiments_name", "super_rank"])

super_rank_df.to_csv(os.path.join(RANKINGS_FOLDER, "super_ranking.csv"), index=False)

print("super ranking saved as ", os.path.join(RANKINGS_FOLDER, "super_ranking.csv"))
# Out:
# super ranking saved as  ./results/all_rankings/super_ranking.csv

# %%
df_privbayes = super_rank_df[super_rank_df["synth_name"] == "privbayes"].copy()
df_gem       = super_rank_df[super_rank_df["synth_name"] == "gem"].copy()
df_aim_jax   = super_rank_df[super_rank_df["synth_name"] == "aim_jax"].copy()

# %%
df_privbayes[df_privbayes['experiments_name'] == 'acs']
# Out:
#    experiments_name                                experiment synth_name  \
# 47              acs                 acs/national/acs/national  privbayes
# 17              acs                acs/national/acs/csv-llama  privbayes
# 41              acs       acs/national/acs/gen-llama-MIX-UNIF  privbayes
# 44              acs  acs/national/acs/massachusetts_upsampled  privbayes
# 11              acs               acs/national/acs/csv-claude  privbayes
# 14              acs                  acs/national/acs/csv-gpt  privbayes
# 29              acs      acs/national/acs/gen-claude-MIX-UNIF  privbayes
# 38              acs        acs/national/acs/gen-llama-MIX-MAX  privbayes
# 26              acs       acs/national/acs/gen-claude-MIX-MAX  privbayes
# 32              acs          acs/national/acs/gen-gpt-MIX-MAX  privbayes
# 56              acs         acs/national/acs/sdscm-olmo-1b-hf  privbayes
# 23              acs             acs/national/acs/gen-MIX-UNIF  privbayes
# 35              acs         acs/national/acs/gen-gpt-MIX-UNIF  privbayes
# 2               acs                acs/national/acs/arbitrary  privbayes
# 20              acs              acs/national/acs/gen-MIX-MAX  privbayes
# 53              acs         acs/national/acs/sdscm-llama-3-8b  privbayes
# 50              acs               acs/national/acs/sdscm-gpt2  privbayes
# 5               acs          acs/national/acs/baseline_domain  privbayes
# 8               acs      acs/national/acs/baseline_univariate  privbayes
#
#     super_rank
# 47    1.000000
# 17    1.633333
# 41    1.766667
# 44    2.022727
# 11    2.100000
# 14    2.100000
# 29    2.100000
# 38    2.100000
# 26    2.283333
# 32    2.283333
# 56    2.283333
# 23    2.300000
# 35    2.300000
# 2     2.383333
# 20    2.400000
# 53    2.550000
# 50    2.933333
# 5     4.466667
# 8     4.516667

# %%
df_privbayes[df_privbayes['experiments_name'] == 'we']
# Out:
#     experiments_name                      experiment synth_name  super_rank
# 290               we                 we/2023/we/2023  privbayes    1.000000
# 287               we                 we/2023/we/2018  privbayes    2.681818
# 335               we           we/2023/we/sdscm-gpt2  privbayes    2.700000
# 317               we   we/2023/we/gen-claude-MIX-MAX  privbayes    2.883333
# 341               we     we/2023/we/sdscm-olmo-1b-hf  privbayes    2.983333
# 338               we     we/2023/we/sdscm-llama-3-8b  privbayes    3.033333
# 293               we            we/2023/we/arbitrary  privbayes    3.150000
# 320               we  we/2023/we/gen-claude-MIX-UNIF  privbayes    3.150000
# 308               we            we/2023/we/csv-llama  privbayes    3.216667
# 305               we              we/2023/we/csv-gpt  privbayes    3.300000
# 311               we          we/2023/we/gen-MIX-MAX  privbayes    3.300000
# 332               we   we/2023/we/gen-llama-MIX-UNIF  privbayes    3.316667
# 323               we      we/2023/we/gen-gpt-MIX-MAX  privbayes    3.366667
# 329               we    we/2023/we/gen-llama-MIX-MAX  privbayes    3.416667
# 302               we           we/2023/we/csv-claude  privbayes    3.483333
# 314               we         we/2023/we/gen-MIX-UNIF  privbayes    3.600000
# 299               we  we/2023/we/baseline_univariate  privbayes    4.016667
# 296               we      we/2023/we/baseline_domain  privbayes    4.150000
# 326               we     we/2023/we/gen-gpt-MIX-UNIF  privbayes    4.366667

# %%
df_privbayes[df_privbayes['experiments_name'] == 'edad']
# Out:
#     experiments_name                          experiment synth_name  \
# 62              edad                 edad/2023/edad/2023  privbayes
# 83              edad          edad/2023/edad/gen-MIX-MAX  privbayes
# 59              edad                 edad/2023/edad/2020  privbayes
# 65              edad            edad/2023/edad/arbitrary  privbayes
# 74              edad           edad/2023/edad/csv-claude  privbayes
# 77              edad              edad/2023/edad/csv-gpt  privbayes
# 86              edad         edad/2023/edad/gen-MIX-UNIF  privbayes
# 80              edad            edad/2023/edad/csv-llama  privbayes
# 92              edad  edad/2023/edad/gen-claude-MIX-UNIF  privbayes
# 89              edad   edad/2023/edad/gen-claude-MIX-MAX  privbayes
# 95              edad      edad/2023/edad/gen-gpt-MIX-MAX  privbayes
# 98              edad     edad/2023/edad/gen-gpt-MIX-UNIF  privbayes
# 110             edad     edad/2023/edad/sdscm-llama-3-8b  privbayes
# 113             edad     edad/2023/edad/sdscm-olmo-1b-hf  privbayes
# 101             edad    edad/2023/edad/gen-llama-MIX-MAX  privbayes
# 107             edad           edad/2023/edad/sdscm-gpt2  privbayes
# 71              edad  edad/2023/edad/baseline_univariate  privbayes
# 68              edad      edad/2023/edad/baseline_domain  privbayes
# 104             edad   edad/2023/edad/gen-llama-MIX-UNIF  privbayes
#
#      super_rank
# 62     1.000000
# 83     1.944444
# 59     2.055556
# 65     2.194444
# 74     2.194444
# 77     2.194444
# 86     2.361111
# 80     2.388889
# 92     2.388889
# 89     2.527778
# 95     2.583333
# 98     3.305556
# 110    3.750000
# 113    4.027778
# 101    4.416667
# 107    4.722222
# 71     5.250000
# 68     5.277778
# 104    5.527778

# %%
super_rank_df["method"] = super_rank_df["experiment"].str.split("/").str[-1]

df_method_avg = (
    super_rank_df
    .groupby("method", as_index=False)["super_rank"]
    .mean()
    .rename(columns={"super_rank": "avg_super_rank"})
)

df_method_avg["super_super_rank"] = df_method_avg["avg_super_rank"].rank(method="dense", ascending=True)

df_method_avg = df_method_avg.sort_values("super_super_rank")

# %%
df_method_avg
# Out:
#                      method  avg_super_rank  super_super_rank
# 11       gen-claude-MIX-MAX        2.422222               1.0
# 7                   csv-gpt        2.524691               2.0
# 3                 arbitrary        2.591975               3.0
# 10             gen-MIX-UNIF        2.624074               4.0
# 12      gen-claude-MIX-UNIF        2.675926               5.0
# 9               gen-MIX-MAX        2.681481               6.0
# 13          gen-gpt-MIX-MAX        2.707407               7.0
# 8                 csv-llama        2.724691               8.0
# 6                csv-claude        2.767901               9.0
# 14         gen-gpt-MIX-UNIF        2.855556              10.0
# 20         sdscm-llama-3-8b        2.861728              11.0
# 21         sdscm-olmo-1b-hf        2.989506              12.0
# 15        gen-llama-MIX-MAX        2.993210              13.0
# 19               sdscm-gpt2        3.068519              14.0
# 16       gen-llama-MIX-UNIF        3.137654              15.0
# 5       baseline_univariate        3.359877              16.0
# 4           baseline_domain        3.662963              17.0
# 0                      2018             NaN               NaN
# 1                      2020             NaN               NaN
# 2                      2023             NaN               NaN
# 17  massachusetts_upsampled             NaN               NaN
# 18                 national             NaN               NaN

# %% [markdown]
# ## Calculating rankings based on advantage
# ### TODO: Currently buggy, need to fix.

# %%
# suppress warnings
import warnings
warnings.filterwarnings("ignore")

column_to_rank_on = 'correspond_test'
for experiments_name, experiments in ALL_EXPERIMENTS_OBJ.items():

    display(Markdown(f"## {experiments_name.upper()}"))

    datasets = {}

    for metric in ydnpd.EVALUATION_METRICS:

        display(Markdown(f"### {metric}"))
        with pd.option_context("display.max_rows", None):
            try: 
                df_extract_all = ydnpd.UtilityTask.evaluate(utility_tasks_results, experiments, metric).multiply(100).round(2)
                
                # flatten df_extract_all
                df_extract_all = df_extract_all.reset_index()

                df_extract_all_smaller = df_extract_all[['synth_name', 'experiment', 'epsilon', column_to_rank_on]] 

                metric_direction = METRIC_DIRECTION[metric]

                df_extract_all_smaller["_raw_value"] = df_extract_all_smaller[column_to_rank_on]

                grp = df_extract_all_smaller.groupby(["experiment", "epsilon"])["_raw_value"]

                if metric_direction in ["closer_to_zero_is_better", "lower_is_better"]:
                    # baseline is best  or lowest in that group
                    baseline_series = grp.transform("min")
                    df_extract_all_smaller["_advantage"] = (
                        baseline_series - df_extract_all_smaller["_raw_value"]
                    ) / baseline_series
                else:
                    # baseline is best or highest in that group
                    baseline_series = grp.transform("max")
                    df_extract_all_smaller["_advantage"] = (
                        df_extract_all_smaller["_raw_value"] - baseline_series
                    ) / baseline_series

                df_extract_all_smaller = df_extract_all_smaller.sort_values(
                    by=["experiment", "epsilon", "_advantage"],
                    ascending=[True, True, False],
                )

                df_extract_all_smaller["_advantage_rank"] = df_extract_all_smaller.groupby(
                    ["experiment", "epsilon"]
                ).cumcount() + 1

                df_experiment_best = (
                    df_extract_all_smaller
                    .groupby(["synth_name", "experiment"], as_index=False)["_advantage_rank"]
                    .min()
                )

                df_final_avg = (
                    df_experiment_best
                    .groupby(["experiment", "synth_name"])["_advantage_rank"]
                    .mean()
                    .reset_index()
                )

                df_final_avg.to_csv(f"./results/advantage_rankings/{metric}_{experiments_name}_advantage.csv")

            except Exception as e:
                print(f"Error: {e}")
                continue
# Out:
# ## ACS
# ### total_variation_distance
# ### marginals_3_max_abs_diff_error
# ### marginals_3_avg_abs_diff_error
# ### thresholded_marginals_3_max_abs_diff_error
# ### thresholded_marginals_3_avg_abs_diff_error
# ### pearson_corr_max_abs_diff
# ### pearson_corr_avg_abs_diff
# ### cramer_v_corr_max_abs_diff
# ### cramer_v_corr_avg_abs_diff
# ### error_rate_diff
# ### error_rate_train_dataset
# ### error_rate_synth_dataset
# ### aoc_diff
# ### aoc_train_dataset
# ### aoc_synth_dataset
# ## EDAD
# ### total_variation_distance
# ### marginals_3_max_abs_diff_error
# ### marginals_3_avg_abs_diff_error
# ### thresholded_marginals_3_max_abs_diff_error
# ### thresholded_marginals_3_avg_abs_diff_error
# ### pearson_corr_max_abs_diff
# ### pearson_corr_avg_abs_diff
# ### cramer_v_corr_max_abs_diff
# ### cramer_v_corr_avg_abs_diff
# ### error_rate_diff
# Error in extractor function:
#  - synth_name: aim_jax
#  - epsilon: 1
#  - dev_name: edad/gen-MIX-MAX
#  - test_name: edad/2023
#  - Error: Cannot index by location index with a non-integer key
# Error in evaluate method: Cannot index by location index with a non-integer key
# Error: Cannot index by location index with a non-integer key
# ### error_rate_train_dataset
# Error in extractor function:
#  - synth_name: aim_jax
#  - epsilon: 1
#  - dev_name: edad/gen-MIX-MAX
#  - test_name: edad/2023
#  - Error: Cannot index by location index with a non-integer key
# Error in evaluate method: Cannot index by location index with a non-integer key
# Error: Cannot index by location index with a non-integer key
# ### error_rate_synth_dataset
# Error in extractor function:
#  - synth_name: aim_jax
#  - epsilon: 1
#  - dev_name: edad/gen-MIX-MAX
#  - test_name: edad/2023
#  - Error: Cannot index by location index with a non-integer key
# Error in evaluate method: Cannot index by location index with a non-integer key
# Error: Cannot index by location index with a non-integer key
# ### aoc_diff
# Error in extractor function:
#  - synth_name: aim_jax
#  - epsilon: 1
#  - dev_name: edad/gen-MIX-MAX
#  - test_name: edad/2023
#  - Error: Cannot index by location index with a non-integer key
# Error in evaluate method: Cannot index by location index with a non-integer key
# Error: Cannot index by location index with a non-integer key
# ### aoc_train_dataset
# Error in extractor function:
#  - synth_name: aim_jax
#  - epsilon: 1
#  - dev_name: edad/gen-MIX-MAX
#  - test_name: edad/2023
#  - Error: Cannot index by location index with a non-integer key
# Error in evaluate method: Cannot index by location index with a non-integer key
# Error: Cannot index by location index with a non-integer key
# ### aoc_synth_dataset
# Error in extractor function:
#  - synth_name: aim_jax
#  - epsilon: 1
#  - dev_name: edad/gen-MIX-MAX
#  - test_name: edad/2023
#  - Error: Cannot index by location index with a non-integer key
# Error in evaluate method: Cannot index by location index with a non-integer key
# Error: Cannot index by location index with a non-integer key
# ## WE
# ### total_variation_distance
# ### marginals_3_max_abs_diff_error
# ### marginals_3_avg_abs_diff_error
# ### thresholded_marginals_3_max_abs_diff_error
# ### thresholded_marginals_3_avg_abs_diff_error
# ### pearson_corr_max_abs_diff
# ### pearson_corr_avg_abs_diff
# ### cramer_v_corr_max_abs_diff
# ### cramer_v_corr_avg_abs_diff
# ### error_rate_diff
# ### error_rate_train_dataset
# ### error_rate_synth_dataset
# ### aoc_diff
# ### aoc_train_dataset
# ### aoc_synth_dataset

# %%
df_final_avg
# Out:
#                         experiment synth_name  _advantage_rank
# 0             we/2023/we/arbitrary    aim_jax             1.25
# 1             we/2023/we/arbitrary        gem             3.00
# 2             we/2023/we/arbitrary  privbayes             1.75
# 3       we/2023/we/baseline_domain    aim_jax             1.75
# 4       we/2023/we/baseline_domain        gem             3.00
# 5       we/2023/we/baseline_domain  privbayes             1.25
# 6   we/2023/we/baseline_univariate    aim_jax             1.25
# 7   we/2023/we/baseline_univariate        gem             3.00
# 8   we/2023/we/baseline_univariate  privbayes             1.75
# 9            we/2023/we/csv-claude    aim_jax             1.25
# 10           we/2023/we/csv-claude        gem             2.75
# 11           we/2023/we/csv-claude  privbayes             2.00
# 12              we/2023/we/csv-gpt    aim_jax             1.00
# 13              we/2023/we/csv-gpt        gem             2.75
# 14              we/2023/we/csv-gpt  privbayes             2.25
# 15            we/2023/we/csv-llama    aim_jax             1.00
# 16            we/2023/we/csv-llama        gem             3.00
# 17            we/2023/we/csv-llama  privbayes             2.00
# 18          we/2023/we/gen-MIX-MAX    aim_jax             1.25
# 19          we/2023/we/gen-MIX-MAX        gem             3.00
# 20          we/2023/we/gen-MIX-MAX  privbayes             1.75
# 21         we/2023/we/gen-MIX-UNIF    aim_jax             1.00
# 22         we/2023/we/gen-MIX-UNIF        gem             3.00
# 23         we/2023/we/gen-MIX-UNIF  privbayes             2.00
# 24   we/2023/we/gen-claude-MIX-MAX    aim_jax             1.25
# 25   we/2023/we/gen-claude-MIX-MAX        gem             3.00
# 26   we/2023/we/gen-claude-MIX-MAX  privbayes             1.75
# 27  we/2023/we/gen-claude-MIX-UNIF    aim_jax             1.25
# 28  we/2023/we/gen-claude-MIX-UNIF        gem             3.00
# 29  we/2023/we/gen-claude-MIX-UNIF  privbayes             1.75
# 30      we/2023/we/gen-gpt-MIX-MAX    aim_jax             1.25
# 31      we/2023/we/gen-gpt-MIX-MAX        gem             3.00
# 32      we/2023/we/gen-gpt-MIX-MAX  privbayes             1.75
# 33     we/2023/we/gen-gpt-MIX-UNIF    aim_jax             1.25
# 34     we/2023/we/gen-gpt-MIX-UNIF        gem             3.00
# 35     we/2023/we/gen-gpt-MIX-UNIF  privbayes             1.75
# 36    we/2023/we/gen-llama-MIX-MAX    aim_jax             1.00
# 37    we/2023/we/gen-llama-MIX-MAX        gem             3.00
# 38    we/2023/we/gen-llama-MIX-MAX  privbayes             2.00
# 39   we/2023/we/gen-llama-MIX-UNIF    aim_jax             1.00
# 40   we/2023/we/gen-llama-MIX-UNIF        gem             3.00
# 41   we/2023/we/gen-llama-MIX-UNIF  privbayes             2.00
# 42           we/2023/we/sdscm-gpt2    aim_jax             1.00
# 43           we/2023/we/sdscm-gpt2        gem             2.75
# 44           we/2023/we/sdscm-gpt2  privbayes             2.25
# 45     we/2023/we/sdscm-llama-3-8b    aim_jax             1.25
# 46     we/2023/we/sdscm-llama-3-8b        gem             2.75
# 47     we/2023/we/sdscm-llama-3-8b  privbayes             2.00
# 48     we/2023/we/sdscm-olmo-1b-hf    aim_jax             1.25
# 49     we/2023/we/sdscm-olmo-1b-hf        gem             3.00
# 50     we/2023/we/sdscm-olmo-1b-hf  privbayes             1.75
